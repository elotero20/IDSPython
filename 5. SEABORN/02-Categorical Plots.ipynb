# %% [markdown]
# ___
#
# <img src='../devf-logo.jpg' />

# %% [markdown]
# # Gráficas de datos categóricos
#
# Estas son las gráficas que podemos utilizar cuando queremos graficar datos categóricos
#
# * factorplot
# * boxplot
# * violinplot
# * stripplot
# * swarmplot
# * barplot
# * countplot

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## barplot y countplot
#
# Esta gráfica nos permite extraer información de datos categóricos en nuestros datasets. Por default, **barplot** nos sirve para obtener medias.

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %% [markdown]
# ### countplot
#
# Esta gráfica es visualmente idéntica a barplot, solo que el estimador por default es el número de ocurrencias de cada categoría.

# %%
sns.countplot(x='sex',data=tips)

# %% [markdown]
# ## boxplot and violinplot

# %%
sns.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
# Podemos graficar todo el dataset de manera horizontal especificando con el parámetro orient='h'
sns.boxplot(data=tips,palette='rainbow',orient='h')

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")

# %% [markdown]
# ### violinplot

# %%
sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',split=True,palette='Set1')

# %% [markdown]
# ## stripplot and swarmplot

# %%
sns.stripplot(x="day", y="total_bill", data=tips)

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True)

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1')

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1',dodge=True)

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)

# %%
sns.swarmplot(x="day", y="total_bill",hue='sex',data=tips, palette="Set1", dodge=True)

# %% [markdown]
# ### Combinando gráficas categóricas

# %%
sns.violinplot(x="tip", y="day", data=tips,palette='rainbow')
sns.swarmplot(x="tip", y="day", data=tips,color='black',size=3)

# %% [markdown]
# ## factorplot
#
# factorplot es la forma más general para realizar un gráfico categórico. Puede tomar cualquier tipo (**kind**) de gráfica para realizar:

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='bar')

# %% [markdown]
# # ¡Excelente trabajo!
